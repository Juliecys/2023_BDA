# %%
import pandas as pd
import csv
import monpa
from monpa import utils
from collections import Counter
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %%
#開檔案
upNews = pd.read_excel('./upNews21-23.xlsx')
upNews.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_time                         title  \
# 0             0           2 2021-01-04        《各報要聞》台積今年資本支出上看200億美元
# 1             1           3 2021-01-04     《半導體》台積電等供應鏈力挺 聯發科Q1拚淡季不淡
# 2             2           4 2021-01-04           《半導體》2021年拚翻身 創意鎖漲停
# 3             3           5 2021-01-04  聯發科外資買盤助攻 股價衝上798元創新高 市值緊追鴻海
# 4             4           6 2021-01-05         《半導體》外資升升升！台積目標價衝到新境界
#
#                                              content  \
# 0  【時報-台北電】晶圓代工龍頭台積電2020年繳出亮麗成績單，預期全年美元營收年成長率逾三成並...
# 1  【時報記者王逸芯台北報導】聯發科(2454)在去年第三季一舉超車高通，在行動晶片市占率衝上3...
# 2  【時報記者王逸芯台北報導】創意(3443)營運最壞時期已經過去，去年第四季在NRE案認列入帳...
# 3  台股今 (14) 日開紅盤，在各國寬鬆貨幣政策下，資金瘋狗浪效應不斷擴散，聯發科 (2454...
# 4  【時報-台北電】台積電（2330）股價新年正開啟新一輪多頭大進擊，外資券商立刻助陣，看好四大...
#
#                                                token label
# 0  ['時報', '台北', '電', '晶圓', '代工', '龍頭', '台積電', '年'...     漲
# 1  ['時報', '記者', '王逸芯', '台北', '報導', '聯發科', '在', '去...     漲
# ...

# %%
downNews = pd.read_excel('./downNews21-23.xlsx')
downNews.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  post_time  \
# 0             0         135 2021-01-20
# 1             1         136 2021-01-20
# 2             2         137 2021-01-20
# 3             3         138 2021-01-20
# 4             4         139 2021-01-20
#
#                                            title  \
# 0  〈台股盤前要聞〉鴻海傳打進Apple Car、義隆攜聚積奪日系遊戲機訂單 今日必看財經新聞
# 1                            【Y早報】拜登就職典禮 市場看好2族群
# 2                            台積電再新天價639元 聯電攀18年高
# 3                《熱門族群》晶圓雙雄好猛！台積電天價650元 聯電續闖18年高
# 4                       台積電今年來股價漲117元 貢獻指數近1000點
#
#                                              content  \
# 0  台股盤前要聞共有九大重點，鴻海傳出已打進 Apple Car 供應鏈，正趕工生產關鍵零組件；...
# 1  （開盤日09:00出刊）拜登就職典禮 市場看好2族群 14檔概念股蓄勢；半導體封測產能吃緊 ...
# 2  （中央社記者張建中新竹2021年1月20日電）晶圓代工廠台積電 (2330) 與聯電 (23...
# 3  【時報記者沈培華台北報導】台積電與聯電美國存託憑證（ADR）同步大漲，帶動兩公司今天股價走高...
# 4  （中央社記者張建中新竹2021年1月20日電）晶圓代工廠台積電 (2330) 股價再創歷史新...
#
#                                                token label
# ...
